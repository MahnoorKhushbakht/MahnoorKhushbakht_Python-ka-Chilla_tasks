# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="ticks", color_codes=True)
land=pd.read_csv("land.csv")
pl=sns.countplot(x='Item', data=land, hue='Flag Description')
pl.set_title("Land")
plt.show()

# %%
# import library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import data from file
land=pd.read_csv("land.csv")
sns.set_theme(style="ticks", color_codes=True)
p= sns.lineplot(x="Year",y="Value",hue="Flag Description",data=land)
plt.show()

# %%
# import library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import data from file
agri=pd.read_csv("agriculture.csv")
sns.set_theme(style="ticks", color_codes=True)
p= sns.barplot(x="Flag",y="Year", hue="Item",data=agri,color="red",ci=0)
pl.set_title("Agriculture")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="whitegrid")
land=pd.read_csv("land.csv")
sns.lineplot(data=land, palette="tab10", linewidth=2.5)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="white")

# Load the example mpg dataset
agri=pd.read_csv("agriculture.csv")

# Plot miles per gallon against horsepower with other semantics
sns.relplot(x="Value", y="Item Code", hue="Item", size="Year",
            sizes=(40, 400), alpha=.5, palette="muted",
            height=6, data=agri)

# %%
import pandas as pd
bgh=pd.read_csv("Bangladesh.csv")
afg=pd.read_csv('Afghanistan.csv')

# %%
bgh.drop(['Note'],axis=1,inplace=True)

# %%
afg.drop(['Note'],axis=1,inplace=True)

# %%
dat=pd.concat([bgh,afg])

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
p= sns.scatterplot(x="Year",y="Value",hue="Area",data=dat)
plt.show()

# %%
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np
sns.set_theme(style="white")
fig = px.pie(dat, values='Value', names='Area')
fig.show()

# %%
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np
sns.set_theme(style="white")
fig = px.scatter(dat, x="Year", y="Value", color="Area",
                 size='Value', hover_data=['Element'])
fig.show()

# %%
import plotly.express as px
import seaborn as sns
import pandas as pd
import numpy as np
fig = px.bar(dat, x='Year', y='Value')
fig.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
agri=pd.read_csv("agriculture.csv")
sns.boxplot(x='Item Code',y='Year',data=agri)
plt.title('Agriculture')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
lc=pd.read_csv("land_cover.csv")
sns.boxplot(x='Flag',y='Value',data=lc,saturation=1)
plt.show()

# %%
import seaborn as sns
import pandas as pd
import numpy as np


sns.set_theme(style="darkgrid")

land=pd.read_csv("land.csv")

# Plot the responses for different events and regions
sns.lineplot(x="Value", y="Year",
             hue="Domain", style="Flag Description",
             data=land)
# Out:
# <AxesSubplot:xlabel='Value', ylabel='Year'>

# %% [markdown]
# - Numpy

# %%
import numpy as np
land=pd.read_csv("land.csv")
land.shape
# Out:
# (89, 14)

# %%
land[2:3]
# Out:
#   Domain Code    Domain  Area Code      Area  Element Code Element  Item Code  \
# 2          RL  Land Use        165  Pakistan          5110    Area       6610
#
#                 Item  Year Code  Year     Unit    Value Flag  \
# 2  Agricultural land       1963  1963  1000 ha  35880.0   Fm
#
#     Flag Description
# 2  Manual Estimation

# %%
land[2:3]=20
land
# Out:
#    Domain Code    Domain  Area Code      Area  Element Code Element  \
# 0           RL  Land Use        165  Pakistan          5110    Area
# 1           RL  Land Use        165  Pakistan          5110    Area
# 2           20        20         20        20            20      20
# 3           RL  Land Use        165  Pakistan          5110    Area
# 4           RL  Land Use        165  Pakistan          5110    Area
# ..         ...       ...        ...       ...           ...     ...
# 84          RL  Land Use        165  Pakistan          5110    Area
# 85          RL  Land Use        165  Pakistan          5110    Area
# 86          RL  Land Use        165  Pakistan          5110    Area
# 87          RL  Land Use        165  Pakistan          5110    Area
# 88          RL  Land Use        165  Pakistan          5110    Area
#
#     Item Code               Item  Year Code  Year     Unit     Value Flag  \
# 0        6610  Agricultural land       1961  1961  1000 ha  35730.00   Fm
# ...

# %%
l1 = np.array(land[:5])
l1
# Out:
# array([['RL', 'Land Use', 165, 'Pakistan', 5110, 'Area', 6610,
#         'Agricultural land', 1961, 1961, '1000 ha', 35730.0, 'Fm',
#         'Manual Estimation'],
#        ['RL', 'Land Use', 165, 'Pakistan', 5110, 'Area', 6610,
#         'Agricultural land', 1962, 1962, '1000 ha', 35840.0, 'Fm',
#         'Manual Estimation'],
#        ['RL', 'Land Use', 165, 'Pakistan', 5110, 'Area', 6610,
#         'Agricultural land', 1963, 1963, '1000 ha', 35880.0, 'Fm',
#         'Manual Estimation'],
#        ['RL', 'Land Use', 165, 'Pakistan', 5110, 'Area', 6610,
#         'Agricultural land', 1964, 1964, '1000 ha', 36355.0, 'Fm',
#         'Manual Estimation'],
#        ['RL', 'Land Use', 165, 'Pakistan', 5110, 'Area', 6610,
#         'Agricultural land', 1965, 1965, '1000 ha', 37235.0, 'Fm',
#         'Manual Estimation']], dtype=object)

# %%
import numpy as np
land=pd.read_csv("land.csv")
l1 = np.array(land[5:])
l1
# Out:
# array([['RL', 'Land Use', 165, ..., 37415.0, 'Fm', 'Manual Estimation'],
#        ['RL', 'Land Use', 165, ..., 37470.0, 'Fm', 'Manual Estimation'],
#        ['RL', 'Land Use', 165, ..., 37170.0, 'Fm', 'Manual Estimation'],
#        ...,
#        ['RL', 'Land Use', 165, ..., 36979.42, 'Fc', 'Calculated data'],
#        ['RL', 'Land Use', 165, ..., 37020.76, 'Fc', 'Calculated data'],
#        ['RL', 'Land Use', 165, ..., 36300.0, 'Fm', 'Manual Estimation']],
#       dtype=object)

# %%
l2=land["Year Code"]
l2
# Out:
# 0     1961
# 1     1962
# 2     1963
# 3     1964
# 4     1965
#       ...
# 84    2017
# 85    2018
# 86    2018
# 87    2019
# 88    2019
# Name: Year Code, Length: 89, dtype: int64

# %%
l2[1]
# Out:
# 1962

# %%
np.sort(l2)
# Out:
# array([1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971,
#        1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982,
#        1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1990, 1991, 1991,
#        1992, 1992, 1993, 1993, 1994, 1994, 1995, 1995, 1996, 1996, 1997,
#        1997, 1998, 1998, 1999, 1999, 2000, 2000, 2001, 2001, 2002, 2002,
#        2003, 2003, 2004, 2004, 2005, 2005, 2006, 2006, 2007, 2007, 2008,
#        2008, 2009, 2009, 2010, 2010, 2011, 2011, 2012, 2012, 2013, 2013,
#        2014, 2014, 2015, 2015, 2016, 2016, 2017, 2017, 2018, 2018, 2019,
#        2019], dtype=int64)

# %%
l2.dtype
# Out:
# dtype('int64')

# %%
s1=l2.astype(float)
s1
# Out:
# 0     1961.0
# 1     1962.0
# 2     1963.0
# 3     1964.0
# 4     1965.0
#        ...
# 84    2017.0
# 85    2018.0
# 86    2018.0
# 87    2019.0
# 88    2019.0
# Name: Year Code, Length: 89, dtype: float64

# %%
s1.dtype
# Out:
# dtype('float64')

# %%
land
# Out:
#    Domain Code    Domain  Area Code      Area  Element Code Element  \
# 0           RL  Land Use        165  Pakistan          5110    Area
# 1           RL  Land Use        165  Pakistan          5110    Area
# 2           50        50         50        50            50      50
# 3           RL  Land Use        165  Pakistan          5110    Area
# 4           RL  Land Use        165  Pakistan          5110    Area
# ..         ...       ...        ...       ...           ...     ...
# 84          RL  Land Use        165  Pakistan          5110    Area
# 85          RL  Land Use        165  Pakistan          5110    Area
# 86          RL  Land Use        165  Pakistan          5110    Area
# 87          RL  Land Use        165  Pakistan          5110    Area
# 88          RL  Land Use        165  Pakistan          5110    Area
#
#     Item Code               Item  Year Code  Year     Unit     Value Flag  \
# 0        6610  Agricultural land       1961  1961  1000 ha  35730.00   Fm
# ...

# %%
land[2:3]*=3
land.head()
# Out:
#   Domain Code    Domain  Area Code      Area  Element Code Element  Item Code  \
# 0          RL  Land Use        165  Pakistan          5110    Area       6610
# 1          RL  Land Use        165  Pakistan          5110    Area       6610
# 2         450       450        450       450           450     450        450
# 3          RL  Land Use        165  Pakistan          5110    Area       6610
# 4          RL  Land Use        165  Pakistan          5110    Area       6610
#
#                 Item  Year Code  Year     Unit    Value Flag  \
# 0  Agricultural land       1961  1961  1000 ha  35730.0   Fm
# 1  Agricultural land       1962  1962  1000 ha  35840.0   Fm
# 2                450        450   450      450    450.0  450
# 3  Agricultural land       1964  1964  1000 ha  36355.0   Fm
# 4  Agricultural land       1965  1965  1000 ha  37235.0   Fm
#
#     Flag Description
# 0  Manual Estimation
# 1  Manual Estimation
# 2                450
# 3  Manual Estimation
# ...

# %%
land["Year Code"] > 1970
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 84     True
# 85     True
# 86     True
# 87     True
# 88     True
# Name: Year Code, Length: 89, dtype: bool

# %%
tot_val=land["Value"]
tot_val
# Out:
# 0     35730.00
# 1     35840.00
# 2       450.00
# 3     36355.00
# 4     37235.00
#         ...
# 84    37003.00
# 85    36300.00
# 86    36979.42
# 87    37020.76
# 88    36300.00
# Name: Value, Length: 89, dtype: float64

# %%
tot_val.sum()
# Out:
# 3201984.3

# %%
tot_val.mean()
# Out:
# 35977.35168539326

# %%
tot_val.mode()
# Out:
# 0    36300.0
# dtype: float64

# %%
import seaborn as sns
import pandas as pd
import numpy as np
sns.set_theme(style="white")
# Load the example mpg dataset
agri=pd.read_csv("agriculture.csv")
agri.describe()
# Out:
#        Area Code  Element Code    Item Code    Year Code         Year  \
# count      177.0         177.0   177.000000   177.000000   177.000000
# mean       165.0        5110.0  6642.000000  1990.000000  1990.000000
# std          0.0           0.0    15.031407    17.077697    17.077697
# min        165.0        5110.0  6621.000000  1961.000000  1961.000000
# 25%        165.0        5110.0  6621.000000  1975.000000  1975.000000
# 50%        165.0        5110.0  6650.000000  1990.000000  1990.000000
# 75%        165.0        5110.0  6655.000000  2005.000000  2005.000000
# max        165.0        5110.0  6655.000000  2019.000000  2019.000000
#
#               Value
# count    177.000000
# mean   12087.028249
# std    13387.595177
# min      150.000000
# 25%      793.000000
# 50%     5000.000000
# 75%    30310.000000
# max    33140.000000
